# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
results = pd.read_excel(r'C:\Users\bruno\OneDrive\Área de Trabalho\Bruno\MBA\Data Wrangling\Data Wrangling Python\(2.2) WDI World Bank.xlsx')
results
# Out:
#                                             Country Name Country Code  \
# 0                                            Afghanistan          AFG
# 1                                            Afghanistan          AFG
# 2                                            Afghanistan          AFG
# 3                                            Afghanistan          AFG
# 4                                            Afghanistan          AFG
# ...                                                  ...          ...
# 383572                                               NaN          NaN
# 383573                                               NaN          NaN
# 383574                                               NaN          NaN
# 383575  Data from database: World Development Indicators          NaN
# 383576                          Last Updated: 03/30/2023          NaN
#
#                                               Series Name        Series Code  \
# ...

# %%
results1 = pd.read_excel(r'C:\Users\bruno\OneDrive\Área de Trabalho\Bruno\MBA\Data Wrangling\Data Wrangling Python\(2.3) WDI Income Group.xlsx')
results1
# Out:
#     Code                                   Long Name         Income Group  \
# 0    AFG                Islamic State of Afghanistan           Low income
# 1    ALB                         Republic of Albania  Upper middle income
# 2    DZA     People's Democratic Republic of Algeria  Lower middle income
# 3    ASM                              American Samoa  Upper middle income
# 4    AND                     Principality of Andorra          High income
# ..   ...                                         ...                  ...
# 260  SSF                          Sub-Saharan Africa                  NaN
# 261  SSA  Sub-Saharan Africa (excluding high income)                  NaN
# 262  TSS             Sub-Saharan Africa (IDA & IBRD)                  NaN
# 263  UMC                         Upper middle income                  NaN
# 264  WLD                                       World                  NaN
#
#                          Region Lending category Other groups   Currency Unit  \
# ...
